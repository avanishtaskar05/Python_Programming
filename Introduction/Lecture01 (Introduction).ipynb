# %% [markdown]
# ## Introduction to Python
# '''
# Data Types of Python
# 1) int : 04
# 2) float : 3.14
# 3) string : Any text value or text form
# 4) bool : True/False
# 5) list : [1,1.222,'India',True,[10],(2),{}]
# 6) tuple : (1,1.222,'India',True,[10],(2),{})
# 7) dictionary : {'Country':['India','Usa']}
# 8) set : {}
# 9) None
# ------------------------------------------------
# # Data Structures of Python
# 1) List : Mutable
# 2) Tuple : Immutable
# 3) Dictionary : Mutable
# 4) Sets : Mutable (It does not contain repeatative values)
# ------------------------------------------------
#
# '''

# %%
print('Hello Avanish')

name='Avanish'
domain='DSDA'
experience=15

#formated string
print(f'my name is {name} and domain {domain}, having exp of {experience}')
# Out:
# Hello Avanish
# my name is Avanish and domain DSDA, having exp of 15

# %% [markdown]
# # Mathematical operators in python
# '''
# Addition +
# Subtraction -
# Multiplication *
# Division / for decimal answer
# Double Division // for whole number answer
# Modulus %
# '''

# %%
name = input ('Enter your name')
print(f'Your name is: {name}')
# Out:
# Your name is: Avanish

# %%
#Concept of typecasting
age = int(input('Enter the age'))
print(type(age))
# Out:
# <class 'int'>

# %%
# Variable Assignment
'''
_num = 100 is considered as valid variable assignment _ is never considered as special character
'''
num1 = 100
num2 = 200
_num = 200
_1num = 300

# Multi Variable Assignment
num1,num2,_,_ = 100,200,300,400
print(num1)
print(num2)
print(_)
# Out:
# 100
# 200
# 400

# %%
# Concept of Indexing & Slicing
'''a[Start : Stop : Step]'''
a = "Hello World"
print(a)
print(a[6:9])
print(a[0::2])
# Out:
# Hello World
# Wor
# HloWrd

# %%
# Write a program whether the entered string is a palindrome or not.

string = input('Enter a string')

string1 = string[::-1]
if string == string1:
    print('Given string is a palindrome')
else:
    print('Given string is not a palindrome')
# Out:
# Given string is not a palindrome
