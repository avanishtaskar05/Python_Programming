# %%
# Logic of for loop
for i in range(0,10,2):
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
#print all  the odd numbers etwee 0 and 10
for i in range(0,10):
    if i%2==1:
        print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
# Data structures in python
# List

lst = []
print(type(lst))

lst.append(1)
print(lst)
# Out:
# <class 'list'>
# [1]

# %%
lst.insert(0,0)
print(lst)
# Out:
# [0, 0]

# %%
lst.extend([2,3,4,5,6,7])
print(lst)
# Out:
# [0, 0, 2, 3, 4, 5, 6, 7]

# %%
lst.pop()
print(lst)
# Out:
# [0, 0, 2, 3, 4, 5, 6]

# %%
lst.append(1)
print(lst)
# Out:
# [0, 0, 2, 3, 4, 5, 6, 1]

# %%
lst.remove(1)
print(lst)
# Out:
# [0, 0, 2, 3, 4, 5, 6]

# %%
lst.count(2)
# Out:
# 1

# %%
lst.sort()
print(lst)
# Out:
# [0, 0, 2, 3, 4, 5, 6]

# %%
lst.reverse()
print(lst)
# Out:
# [6, 5, 4, 3, 2, 0, 0]

# %%
lst.index(2)
# Out:
# 4

# %%
a = lst.copy()
print(lst)
print(a)
# Out:
# [6, 5, 4, 3, 2, 0, 0]
# [6, 5, 4, 3, 2, 0, 0]

# %%
# list indexing and slicing
a = [10,20,30,[40,[100,200],300,400],900]
a[3][1][0]
# Out:
# 100
