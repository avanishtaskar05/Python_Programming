# %%
class bank:
    def __init__(self, acct_no, 
                 acct_holder, acct_type, 
                 age, gender, 
                 email_id, KYC,
                 user_id, passcode, 
                 balance):
        self.acct_no = acct_no
        self.acct_holder = acct_holder
        self.acct_type = acct_type
        self.age = age
        self.gender = gender
        self.email_id = email_id
        self.KYC = KYC
        self.__user_id = user_id
        self.__passcode = passcode
        self.balance = balance 

    def credit(self, amount, balance):
        self.amount = amount
        self.balance = balance     

    def debit(self, amount, balance = 1000):
        self.amount = amount
        self.balance = balance
        
    
    def balance(self):
        pass

# %%
class saving_acct(bank):


#Define constructor
    def _init_(self,interest_rate,tenure):
        super()._init_(self, acct_no, 
                 acct_holder, acct_type, 
                 age, gender, 
                 email_id, KYC,
                 user_id, passcode, 
                 balance)
        
        self.interest_rate = interest_rate
        self.tenure = tenure
        
#Define method : credit_info
    def credit_info(self,amount,balance = 10000):
        self.amount=amount
        self.balance=balance

        print(f'the actual balance is {self.balance}')
        print(f'the credited amount is {self.amount}')
        print(f'the balance after credit is {self.balance + self.amount}')

    def debit_info(self,amount,balance = 10000):
        if (user_id.lower() == 'rama123') and (passcode == 'rama@20'):
            self.amount=amount
            self.balance=balance

            print(f'the actual balance is {self.balance}')
            print(f'the debited amount is {self.amount}')
            print(f'the balance after debit is {self.balance - self.amount}')
        else:
            print('Invalid user_id or passcode. Access denied.')

# %%
acct_no = input("Enter account number: ")
acct_holder = input("Enter account holder name: ")
acct_type = input("Enter account type: ")
age = int(input("Enter age: "))
gender = input("Enter gender: ")
email_id = input("Enter email ID: ")
KYC = input("Enter KYC status: ")
user_id = input("Enter user ID: ")
passcode = input("Enter passcode: ")
balance = float(input("Enter initial balance: "))

# %%
tjsb_1 = saving_acct(8, 5)
tjsb_1.credit_info(amount,balance)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 tjsb_1 = saving_acct(8, 5)
#       2 tjsb_1.credit_info(amount,balance)
#
# TypeError: saving_acct() takes no arguments

# %%
saving_acct.credit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 saving_acct.credit()
#
# NameError: name 'saving_acct' is not defined

# %%
from abc import ABC,abstractmethod
class bank(ABC):
    @abstractmethod
    def credit(self):
        pass

    @abstractmethod
    def debit(self):
        pass

    @abstractmethod
    def balance(self):
        pass

# %%
class saving_acct(bank):
    def credit(self):
        pass

    def debit(self):
        pass

    def balance(self):
        pass
