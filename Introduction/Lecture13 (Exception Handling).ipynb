# %%
'''
try:
statements

excepts:
statements

else:
statements

finally:
statements
'''
# Out:
# '\ntry:\nstatements\n\nexcepts:\nstatements\n\nelse:\nstatements\n\nfinally:\nstatements\n'

# %%
try:
    num1 = 100
    num2 = 0
    result = num1 / num2
except ZeroDivisionError:
    print('Zero Division Error... Please check your calculation')
# Out:
# Zero Division Error... Please check your calculation

# %%
try:
    num1 = int(input("Enter a number: "))
    num2 = int(input("Enter another number: "))
    age = int(input("Enter your age: "))
    string1 = "Hello"
    result = num1 + string1
except ValueError:
    print('Check the inputed values')
except TypeError:
    print('Check the calculation as you have entered a string and a number')
# Out:
# Check the calculation as you have entered a string and a number

# %%
numbers = [1, 2, 3, 4, 5]
try:
    print(numbers[10])
except IndexError:
    print('Index does not exists')
# Out:
# Index does not exists

# %%
# Handling exception as object
try:
    result = 10 / 0
except ZeroDivisionError as e:
    print('Exception message:',e)
    print('Exception type:',type(e).__name__)
# Out:
# Exception message: division by zero
# Exception type: ZeroDivisionError

# %%
num1 = 100
num2 = 20
try:
    result = num1 / num2
except ZeroDivisionError:
    print('Cannot divide by zero')
else:
    print("Division successful")
    print("Result:",result)
# Out:
# Division successful
# Result: 5.0

# %%
class bank:
    def __init__(self, name, age, gender):
    try:
        self.name = name
        self.age = age
        self.gender = gender

    except ValueError:
        print('Check the inputed values')
    excep
# Out:
#   Cell In[10], line 1
#     class bank:
#                ^
# _IncompleteInputError: incomplete input
