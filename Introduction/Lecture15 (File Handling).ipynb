# %%
#import logging
import logging
logging.basicConfig(level = logging.INFO,
                   filename = 'filehandling.log',
                   filemode = 'w',
                   format = '%(asctime)s - %(levelname)s - %(message)s',
                   force = True)

# %%
# Import Data: Data Ingestion: Loading data into system
# Go to cmd type: type nul > demo.txt 
# To create a full using terminal
try:
    logging.info('Data Ingestion Started')
    with open (r"C:\Python_Programming\demo1.txt", "w") as file:
        print(file.write("\nGood Evening"))
        logging.info('Data Updated')
    with open (r"C:\Python_Programming\demo.txt", "r") as file:
        print(file.read())
except:
    logging.info('Check the file location properly')
# Out:
# 13
# Good EveningGood Evening
# Good Evening
# Good Evening

# %%
# lambda function
square = lambda x: x ** 2
square(5)
# Out:
# 25

# %%
def square(num):        # function defination
    num = num ** 2
    return num
num = float(input('Enter a number:'))
ans = square(num)       # function calling

print(ans)

# %% [markdown]
# # I
