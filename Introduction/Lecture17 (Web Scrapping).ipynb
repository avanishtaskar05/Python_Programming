# %%
import requests
import re
import os
import sys

url = 'https://quotes.toscrape.com/'

response = requests.get(url)
print(type(response))
print(response.status_code)
print(response.text)
# Out:
# <class 'requests.models.Response'>
# 200
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta charset="UTF-8">
# 	<title>Quotes to Scrape</title>
#     <link rel="stylesheet" href="/static/bootstrap.min.css">
#     <link rel="stylesheet" href="/static/main.css">
#
#
# </head>
# <body>
#     <div class="container">
#         <div class="row header-box">
#             <div class="col-md-8">
#                 <h1>
#                     <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#                 </h1>
#             </div>
#             <div class="col-md-4">
#                 <p>
#
#                     <a href="/login">Login</a>
#
#                 </p>
#             </div>
#         </div>
#
#
# <div class="row">
#     <div class="col-md-8">
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
# ...

# %%
import BeautifulSoup

html = "<h1> Hello my name is Avanish</h1>" \
"<p>Version: 1.0.0"

info = bs4.BeautifuleSoup(html)
print(info.text)
print(info.find('h1'))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 import BeautifulSoup
#       2
#       3 html = "<h1> Hello my name is Avanish</h1>" \
#       4 "<p>Version: 1.0.0"
#
# ModuleNotFoundError: No module named 'BeautifulSoup'

# %%
data = info.findall('h1')
for i in data:
    print(i.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 data = info.findall('h1')
#       2 for i in data:
#       3     print(i.text)
#
# NameError: name 'info' is not defined

# %%
import pandas as pd
data  = info.find_all('h1')
content=[]
for i in data:
    content.append(i.text)
df = pd.DataFrame(content,columns= ['Scrape Information'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 import pandas as pd
# ----> 2 data  = info.find_all('h1')
#       3 content=[]
#       4 for i in data:
#       5     content.append(i.text)
#
# NameError: name 'info' is not defined
